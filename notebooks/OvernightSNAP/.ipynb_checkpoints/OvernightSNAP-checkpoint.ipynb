# %%
# Program to read in pkl files containing data from a long
# obseration with the SNAPs at the ATA. This example shows 
# processing three antennas, 6 pols, and the data. Edit the 
# code to fit your needs.
#
# Author: Jon Richards, SETI Institute
# Date: June 28, 2019
#

# %%
import sys
import os
import glob
import pickle
import numpy as np, scipy.io
import math
from pylab import rcParams
import pylab as plt
import matplotlib.dates as mdates
from datetime import datetime

# %%
# Define the ants to use
ant1 = '2j'
ant2 = '4j'
ant3 = '5c'

#Define your data and output images directory
data_dir = "./data" # Copy the pkl data files into here
images_dir = "./images"

# %%
# Get the list of files
print("Reading in data - this takes a while if you have a lot of files...")
file_list1 = glob.glob(data_dir + "/*" + ant1 + "*.pkl")
file_list1.sort() # The first field is the timestamp, order by time
file_list2 = glob.glob(data_dir + "/*" + ant2 + "*.pkl")
file_list2.sort() # The first field is the timestamp, order by time
file_list3 = glob.glob(data_dir + "/*" + ant3 + "*.pkl")
file_list3.sort() # The first field is the timestamp, order by time
print("Reading in data - Finished")
#for fname in file_list1:
#    print(fname)
#for fname in file_list2:
#    print(fname)
#for fname in file_list3:
#    print(fname)
# Out:
# Reading in data - this takes a while if you have a lot of files...
# Reading in data - Finished

# %%
#Creat the lists to store the data
power1_x = list()
power1_y = list()
power2_x = list()
power2_y = list()
power3_x = list()
power3_y = list()

#This is a list of times for each data point, read in 
#from the first set of file.
times = list()

# %%
#Read in the data

for fname in file_list1:
    
    print("Processing file: " + fname)
    
    f = open(fname,'r')
    data = pickle.load(f)
    
    # Create one big list of unix timestamps for each data point
    times.extend(data['auto0_timestamp'])

    for d in data['auto0']:
        power1_x.append(np.median(10*np.log10(d[768:1700])))
        
    for d in data['auto1']:
        power1_y.append(np.median(10*np.log10(d[768:1700])))
        
for fname in file_list2:
    
    print("Processing file: " + fname)
    
    f = open(fname,'r')
    data = pickle.load(f)
    
    for d in data['auto0']:
        power2_x.append(np.median(10*np.log10(d[768:1700])))

    for d in data['auto1']:
        power2_y.append(np.median(10*np.log10(d[768:1700])))
        
for fname in file_list3:
    
    print("Processing file: " + fname)
    
    f = open(fname,'r')
    data = pickle.load(f)
    
    for d in data['auto0']:
        power3_x.append(np.median(10*np.log10(d[768:1700])))
    for d in data['auto1']:
        power3_y.append(np.median(10*np.log10(d[768:1700])))
        
#For sanity, plint out how many data points there are
#for each pol. They should all be the same.
print(len(power1_x),len(power1_y))
print(len(power2_x),len(power2_y))
print(len(power3_x),len(power3_y))
# Out:
# Processing file: ./data3/1561683122_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_1.pkl
# Processing file: ./data3/1561684342_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_2.pkl
# Processing file: ./data3/1561685558_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_3.pkl
# Processing file: ./data3/1561686771_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_4.pkl
# Processing file: ./data3/1561687986_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_5.pkl
# Processing file: ./data3/1561689200_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_6.pkl
# Processing file: ./data3/1561690416_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_7.pkl
# Processing file: ./data3/1561691632_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_8.pkl
# Processing file: ./data3/1561692852_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_9.pkl
# Processing file: ./data3/1561694072_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_10.pkl
# Processing file: ./data3/1561695288_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_11.pkl
# Processing file: ./data3/1561696504_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_12.pkl
# Processing file: ./data3/1561697733_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_13.pkl
# Processing file: ./data3/1561698947_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_14.pkl
# Processing file: ./data3/1561700161_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_15.pkl
# Processing file: ./data3/1561701374_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_16.pkl
# Processing file: ./data3/1561702588_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz_17.pkl
# Processing file: ./data3/1561703804_rf3500.00_n1000_north_2j_on_allnight_obsid10000003_3500mhz
rf3500.00_n1000_3c380_4j_on_allnight_obsid10000003_3500mhz_40.pkl
# Processing file: ./data3/1561731782_rf3500.00_n1000_3c380_4j_on_allnight_obsid10000003_3500mhz_41.pkl
# Processing file: ./data3/1561732997_rf3500.00_n1000_3c380_4j_on_allnight_obsid10000003_3500mhz_42.pkl
# Processing file: ./data3/1561734210_rf3500.00_n1000_3c380_4j_on_allnight_obsid10000003_3500mhz_43.pkl
# Processing file: ./data3/1561735423_rf3500.00_n1000_3c380_4j_on_allnight_obsid10000003_3500mhz_44.pkl
# Processing file: ./data3/1561736637_rf3500.00_n1000_3c380_4j_on_allnight_obsid10000003_3500mhz_45.pkl
# Processing file: ./data3/1561683136_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_1.pkl
# Processing file: ./data3/1561684349_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_2.pkl
# Processing file: ./data3/1561685564_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_3.pkl
# Processing file: ./data3/1561686777_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_4.pkl
# Processing file: ./data3/1561687994_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_5.pkl
# Processing file: ./data3/1561689208_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_6.pkl
# Processing file: ./data3/1561690419_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_7.pkl
# Processing file: ./data3/1561691633_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_8.pkl
# Processing file: ./data3/1561692852_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_9.pkl
# Processing file: ./data3/1561694071_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_10.pkl
# Processing file: ./data3/1561695285_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_11.pkl
# Processing file: ./data3/1561696496_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_12.pkl
# Processing file: ./data3/1561697723_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_13.pkl
# Processing file: ./data3/1561698939_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_14.pkl
# Processing file: ./data3/1561700155_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_15.pkl
# Processing file: ./data3/1561701368_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_16.pkl
# Processing file: ./data3/1561702581_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_17.pkl
# Processing file: ./data3/1561703794_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_18.pkl
# Processing file: ./data3/1561705012_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_19.pkl
# Processing file: ./data3/1561706230_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_20.pkl
# Processing file: ./data3/1561707447_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_21.pkl
# Processing file: ./data3/1561708665_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_22.pkl
# Processing file: ./data3/1561709882_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_23.pkl
# Processing file: ./data3/1561711100_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_24.pkl
# Processing file: ./data3/1561712310_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_25.pkl
# Processing file: ./data3/1561713527_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_26.pkl
# Processing file: ./data3/1561714739_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_27.pkl
# Processing file: ./data3/1561715952_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_28.pkl
# Processing file: ./data3/1561717165_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_29.pkl
# Processing file: ./data3/1561718375_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_30.pkl
# Processing file: ./data3/1561719587_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_31.pkl
# Processing file: ./data3/1561720800_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_32.pkl
# Processing file: ./data3/1561722021_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_33.pkl
# Processing file: ./data3/1561723235_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_34.pkl
# Processing file: ./data3/1561724450_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_35.pkl
# Processing file: ./data3/1561725660_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_36.pkl
# Processing file: ./data3/1561726876_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_37.pkl
# Processing file: ./data3/1561728091_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_38.pkl
# Processing file: ./data3/1561729303_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_39.pkl
# Processing file: ./data3/1561730516_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_40.pkl
# Processing file: ./data3/1561731728_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_41.pkl
# Processing file: ./data3/1561732939_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_42.pkl
# Processing file: ./data3/1561734150_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_43.pkl
# Processing file: ./data3/1561735362_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_44.pkl
# Processing file: ./data3/1561736574_rf3500.00_n1000_north_5c_on_allnight_obsid10000003_3500mhz_45.pkl
# (45000, 45000)
# (45000, 45000)
# (45000, 45000)

# %%
#Convert the list of times from unix timestamp to Datetime objects.
timesd = list()
for ts in times:
    timesd.append(datetime.fromtimestamp(int(ts)))
times = timesd
rcParams['figure.figsize'] = 20, 6

plt.plot(timesd, power1_x, c='#cc0000', label='North X pol (2j)')
plt.plot(timesd, power1_y, c='#0000ff', label='North Y pol (2j)')
plt.plot(timesd, power2_x, c='#39ff14', label='3c380 X pol (4j)')
plt.plot(timesd, power2_y, c='#00cccc', label='3c380 Y pol (4j)')
plt.plot(timesd, power3_x, c='#000000', label='North X pol (5c)')
plt.plot(timesd, power3_y, c='#dd88aa', label='North Y pol (5c)')

plt.legend()

#If you want to create an image file...
#plt.savefig(images_dir + '/pic.png')

plt.show()
